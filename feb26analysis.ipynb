# %%
import pandas as pd

# %%
df = pd.read_csv("RAYMOND RUN PLANNING - Z7. 5x1200 02262025.csv")
df
# Out:
#    LAP    TIME    CUMT  DMILE µPACE / mi  µGAP / mi    µHR  MAXHR  \
# 0    1  0:39.5  0:39.5   0.11       6:13        NaN  100.0  124.0
# 1    2  0:41.1  1:20.5   0.11       6:14        NaN  137.0  145.0
# 2    3  0:41.9  2:02.5   0.11       6:26        NaN  149.0  152.0
# 3    4  0:42.6  2:45.1   0.10       6:51        NaN  155.0  157.0
# 4    5  0:41.8  3:26.9   0.10       6:43        NaN  158.0  160.0
# 5    6  0:40.7  4:07.6   0.11       6:17        NaN  161.0  162.0
# 6   R1     NaN     NaN    NaN        NaN        NaN    NaN    NaN
# 7    8  0:42.4  7:31.3   0.11       6:10        NaN  142.0  155.0
# 8    9  0:42.7  8:14.0   0.11       6:45        NaN  160.0  163.0
# 9   10  0:43.5  8:57.5   0.11       6:38        NaN  165.0  167.0
# 10  11  0:44.1  9:41.6   0.11       6:48        NaN  167.0  168.0
# 11  12  0:43.3   10:25   0.11       6:48        NaN  183.0  186.0
# 12  13  0:42.2   11:07   0.11       6:28        NaN  185.0  187.0
# ...
